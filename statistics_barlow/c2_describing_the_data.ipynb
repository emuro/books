# %%
import random
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # C2. Describing the Data

# %%
head_tail = ["".join(random.choice("HT")) for i in range(0,10)]
print(head_tail)
df = pd.DataFrame(head_tail, columns=["toss_coin"])
print(df)
df.info()
# Out:
# ['T', 'H', 'H', 'T', 'T', 'H', 'H', 'T', 'T', 'H']
#   toss_coin
# 0         T
# 1         H
# 2         H
# 3         T
# 4         T
# 5         H
# 6         H
# 7         T
# 8         T
# 9         H
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   toss_coin  10 non-null     object
# dtypes: object(1)
# memory usage: 208.0+ bytes

# %%
# setting font sizeto 30
plt.rcParams.update({'font.size': 30})

fig, ax = plt.subplots(figsize=(10,10))
ax = df.toss_coin.value_counts().plot.bar(color=["red", "blue"])
ax.set_title("Tossing a coin")
ax.set_ylabel("Number")
ax.set_xlabel("Event")
plt.show()
