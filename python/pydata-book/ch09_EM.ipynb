# %% [markdown]
# # Plotting and Visualization

# %%
import numpy as np
import pandas as pd
PREVIOUS_MAX_ROWS = pd.options.display.max_rows
pd.options.display.max_rows = 20
np.random.seed(12345)
import matplotlib.pyplot as plt
import matplotlib
plt.rc('figure', figsize=(10, 6))
np.set_printoptions(precision=4, suppress=True)

# %% [markdown]
# %matplotlib notebook

# %% [markdown]
# ## A Brief matplotlib API Primer

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
data = np.arange(10)
data
plt.plot(data)

# %% [markdown]
# ### Figures and Subplots

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2, 2, 1)
plt.plot(data)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
plt.plot(np.random.standard_normal(50).cumsum(), color="black", linestyle="dashed")
ax4 = fig.add_subplot(2, 2, 4)
plt.plot(np.random.standard_normal(50).cumsum(), color="black", linestyle="dotted")
#
ax1.hist(np.random.standard_normal(100), bins=20, color="red", alpha=0.2);
ax2.scatter(np.arange(30), np.arange(30) + 3 * np.random.standard_normal(30));
ax2.scatter(np.arange(20), np.arange(20), s=1, color="purple", alpha=0.4);

# %%
#fig, axes = plt.subplots(2, 3, sharex=True, sharey=True)
fig, axes = plt.subplots(2, 3)
axes
# Out:
# array([[<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
axes[0,2]
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Adjusting the spacing around plots

# %%
fig, axes = plt.subplots(2,2, sharex=True, sharey=True)
for i in range(2):
    for j in range(2):
        axes[i,j].hist(np.random.standard_normal(500), bins=50, 
                       color="black", alpha=0.5)
fig.subplots_adjust(wspace=0., hspace=0.)

# %% [markdown]
# ### Color, Markers, and Line Styles

# %%
#ax.plot(x, y, linestyle="--", color="green")

# %%
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(np.random.standard_normal(30).cumsum(), color="black",
        linestyle="dashed", marker="o");

# %%
fig = plt.figure()
ax = fig.add_subplot()
data = np.random.standard_normal(30).cumsum()
ax.plot(data, color="blue", linestyle="dashed", label="Tigres");
ax.plot(data, color="orange", linestyle="dotted",
        drawstyle="steps-post", label="Leones");
ax.legend()

# %% [markdown]
# ### Ticks, Labels, and Legends

# %%
fig, ax = plt.subplots()
ax.plot(np.random.standard_normal(1000).cumsum());

# %%
fig, ax = plt.subplots()
ax.plot(np.random.standard_normal(1000).cumsum());
ticks = ax.set_xticks([0,250,500,750,1000])
ticks = ax.set_xticklabels(["a","b","c","d","escara"], rotation=30, fontsize=10)
ax.set_xlabel("Eje de las x")
ax.text(5, -3.666666666666652, 'Stages')
#ax.set_title("My first matplotlib plot");
ax.set(title="My first matplotlib plot", ylabel="Eje y")
# Out:
# [Text(0.5, 1.0, 'My first matplotlib plot'), Text(0, 0.5, 'Eje y')]

# %%
ax.set(title="My first matplotlib plot", xlabel="Stages")
# Out:
# [Text(0.5, 1.0, 'My first matplotlib plot'),
#  Text(0.5, 17.200000000000003, 'Stages')]

# %% [markdown]
# *Adding legends*

# %%
fig, ax = plt.subplots()
ax.plot(np.random.randn(1000).cumsum(), color="black", label="one");
ax.plot(np.random.randn(1000).cumsum(), color="red", 
        linestyle="dashed", label="two");
ax.plot(np.random.randn(1000).cumsum(), color="blue", 
        linestyle="dotted", label="three");
ax.plot(np.random.randn(1000).cumsum(), color="green", 
        linestyle="dotted", label="four");
ax.legend()

# %% [markdown]
# ### Annotations and Drawing on a Subplot

# %%
ax.text(200,-20, "This is a annotations", family="monospace", fontsize=10)
# Out:
# Text(200, -20, 'This is a annotations')

# %%
fig, ax = plt.subplots()
ax.plot(np.random.randn(1000).cumsum(), color="black", label="one");
ax.plot(np.random.randn(1000).cumsum(), color="red", 
        linestyle="dashed", label="two");
ax.plot(np.random.randn(1000).cumsum(), color="blue", 
        linestyle="dotted", label="three");
ax.plot(np.random.randn(1000).cumsum(), color="green", 
        linestyle="dotted", label="four");
ax.text(20,-0, "These are some annotations", family="monospace", fontsize=10)
# Out:
# Text(20, 0, 'These are some annotations')

# %%
from datetime import datetime

# %%
# system
import os
system = list(os.uname())[0]
if system == 'Linux':
    base_dir = "/home/emuro/git/github/"
elif system == 'Darwin':
    base_dir = "~/PycharmProjects/"
base_dir += "pydata-book/"
print(base_dir)
# Out:
# /home/emuro/git/github/pydata-book/

# %%
spx_f = base_dir + 'examples/spx.csv'
#!cat $spx_f

# %%
fig, ax = plt.subplots()

data = pd.read_csv(spx_f, index_col=0, parse_dates=True)
spx = data["SPX"]

spx.plot(ax=ax, color="black")
crisis_data = [
    (datetime(2007, 10, 11), "Peak of bull market"),
    (datetime(2008, 3, 12), "Bear Stearns Fails"),
    (datetime(2008, 9, 15), "Lehman Bankruptcy")
]

for date, label in crisis_data:
    ax.annotate(label, xy=(date, spx.asof(date) + 75),
                xytext=(date, spx.asof(date) + 225),
                arrowprops=dict(facecolor="black", headwidth=4, width=2,
                                headlength=4),
                horizontalalignment="left", verticalalignment="top")

# Zoom in on 2007-2010
ax.set_xlim(["1/1/2007", "1/1/2011"])
ax.set_ylim([600, 1800])
ax.set_title("Important dates in the 2008-2009 financial crisis");

# %%
matplotlib.patches?
# Out:
# Type:        module
# String form: <module 'matplotlib.patches' from '/home/emuro/python-my_venv/python3.10/my_env/lib/python3.10/site-packages/matplotlib/patches.py'>
# File:        ~/python-my_venv/python3.10/my_env/lib/python3.10/site-packages/matplotlib/patches.py
# Docstring:   Patches are `.Artist`\s with a face color and an edge color.

# %%
fig, ax = plt.subplots()

rect = plt.Rectangle((0.2, 0.7), 0.5, 0.15, color="black", alpha=0.3)
ax.add_patch(rect)

circ = plt.Circle((0.7, 0.2), 0.15, color="blue", alpha=0.3)
ax.add_patch(circ)

pgon = plt.Polygon([[0.15, 0.15], [0.4, 0.2], [0.35, 0.4], [0.2, 0.6]], color="green", alpha=0.5)
#pgon = plt.Polygon([[0.15, 0.15], [0.35, 0.4], [0.2, 0.6]],color="green", alpha=0.5)
ax.add_patch(pgon);

# %% [markdown]
# ### Saving Plots to File

# %%
# fig.savefig("figpath.svg")
# fig.savefig("figpath.png", dpi=400)

# %% [markdown]
# ### matplotlib Configuration

# %%
plt.rc("figure", figsize=(10, 10))

# %%
#plt.rcParams
plt.rcdefaults()

# %%
plt.rc("font", family="monospace", weight="bold", size=8)

# %% [markdown]
# ## Plotting with pandas and seaborn

# %% [markdown]
# ### Line Plots

# %%
s = pd.Series(np.random.standard_normal(10).cumsum(), index=np.arange(0, 100, 10))
s.plot();

# %%
df = pd.DataFrame(np.random.standard_normal((10, 4)).cumsum(0),
                  columns=["A", "B", "C", "D"],
                  index=np.arange(0, 100, 10))
df.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Bar plots

# %%
data = pd.Series(np.random.uniform(size=16), index=list("ramonesundma1234"))
data.plot.bar(color="green", alpha=0.2)
#data.plot.barh(color="purple", alpha=0.9, xticks=np.arange(0,1,0.05), rot=30)
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.uniform(size=(6, 4)),
                  index=["one", "two", "three", "four", "five", "six"],
                  columns=pd.Index(["A", "B", "C", "D"], name="Genus"))

df
# Out:
# Genus         A         B         C         D
# one    0.252328  0.674091  0.114144  0.994305
# two    0.073215  0.643971  0.568905  0.074991
# three  0.495372  0.579601  0.885070  0.096525
# four   0.642303  0.787628  0.809251  0.405936
# five   0.917079  0.298153  0.919056  0.629700
# six    0.962607  0.172832  0.145627  0.667433

# %%
df.plot.barh(stacked=True, alpha=0.3);

# %%
df.plot.barh(stacked=True, alpha=0.3);

# %%
tips_f = base_dir + 'examples/tips.csv'
#!cat $tips_f
tips = pd.read_csv(tips_f)
display(tips.head())
# Out:
#    total_bill   tip smoker  day    time  size
# 0       16.99  1.01     No  Sun  Dinner     2
# 1       10.34  1.66     No  Sun  Dinner     3
# 2       21.01  3.50     No  Sun  Dinner     3
# 3       23.68  3.31     No  Sun  Dinner     2
# 4       24.59  3.61     No  Sun  Dinner     4

# %%
tips["time"].value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %%
party_counts = pd.crosstab(tips["day"], tips["size"])
party_counts
# Out:
# size  1   2   3   4  5  6
# day
# Fri   1  16   1   1  0  0
# Sat   2  53  18  13  1  0
# Sun   0  39  15  18  3  1
# Thur  1  48   4   5  1  3

# %%
party_counts = party_counts.reindex(index=["Thur", "Fri", "Sat", "Sun"])
party_counts
# Out:
# size  1   2   3   4  5  6
# day
# Thur  1  48   4   5  1  3
# Fri   1  16   1   1  0  0
# Sat   2  53  18  13  1  0
# Sun   0  39  15  18  3  1

# %%
party_counts = party_counts.loc[:, 2:5]

# %%
# total = party_counts.sum(axis="columns")

# %%
party_pcts = party_counts.div(party_counts.sum(axis="columns"), axis="index")

# %%
display(party_pcts)
party_pcts.plot.barh(stacked=True);
# Out:
# size         2         3         4         5
# day
# Thur  0.827586  0.068966  0.086207  0.017241
# Fri   0.888889  0.055556  0.055556  0.000000
# Sat   0.623529  0.211765  0.152941  0.011765
# Sun   0.520000  0.200000  0.240000  0.040000

# %% [markdown]
# *With seaborn*

# %%
tips
# Out:
#      total_bill   tip smoker   day    time  size
# 0         16.99  1.01     No   Sun  Dinner     2
# 1         10.34  1.66     No   Sun  Dinner     3
# 2         21.01  3.50     No   Sun  Dinner     3
# 3         23.68  3.31     No   Sun  Dinner     2
# 4         24.59  3.61     No   Sun  Dinner     4
# ..          ...   ...    ...   ...     ...   ...
# 239       29.03  5.92     No   Sat  Dinner     3
# 240       27.18  2.00    Yes   Sat  Dinner     2
# 241       22.67  2.00    Yes   Sat  Dinner     2
# 242       17.82  1.75     No   Sat  Dinner     2
# 243       18.78  3.00     No  Thur  Dinner     2
#
# [244 rows x 6 columns]

# %%
import seaborn as sns

# %%
tips["tip_pct"] = tips["tip"]/(tips["total_bill"] - tips["tip"])
tips.head()
# Out:
#    total_bill   tip smoker  day    time  size   tip_pct
# 0       16.99  1.01     No  Sun  Dinner     2  0.063204
# 1       10.34  1.66     No  Sun  Dinner     3  0.191244
# 2       21.01  3.50     No  Sun  Dinner     3  0.199886
# 3       23.68  3.31     No  Sun  Dinner     2  0.162494
# 4       24.59  3.61     No  Sun  Dinner     4  0.172069

# %%
sns.barplot(x="tip_pct", y="day", data=tips, orient="h");

# %%
sns.barplot(x="tip_pct", y="day", data=tips, orient="h", hue="time");

# %%
sns.set_style("whitegrid")
sns.barplot(x="tip_pct", y="day", data=tips, orient="h", hue="time");

# %%
sns.set_palette("Greys_r")
sns.barplot(x="tip_pct", y="day", data=tips, orient="h", hue="time");

# %% [markdown]
# ### History and Density Plots

# %%
display(tips)

sns.set_theme() # default
tips["tip_pct"].plot.hist(bins=100);
# Out:
#      total_bill   tip smoker   day    time  size   tip_pct
# 0         16.99  1.01     No   Sun  Dinner     2  0.063204
# 1         10.34  1.66     No   Sun  Dinner     3  0.191244
# 2         21.01  3.50     No   Sun  Dinner     3  0.199886
# 3         23.68  3.31     No   Sun  Dinner     2  0.162494
# 4         24.59  3.61     No   Sun  Dinner     4  0.172069
# ..          ...   ...    ...   ...     ...   ...       ...
# 239       29.03  5.92     No   Sat  Dinner     3  0.256166
# 240       27.18  2.00    Yes   Sat  Dinner     2  0.079428
# 241       22.67  2.00    Yes   Sat  Dinner     2  0.096759
# 242       17.82  1.75     No   Sat  Dinner     2  0.108899
# 243       18.78  3.00     No  Thur  Dinner     2  0.190114
#
# [244 rows x 7 columns]

# %%
tips["tip_pct"].plot.density();

# %%
comp1 = np.random.standard_normal(200)
comp2 = 10 + 2. * np.random.standard_normal(200)
values = pd.Series(np.concatenate([comp1, comp2]))
sns.histplot(values, bins=50, color="orange");

# %% [markdown]
# ### Scatter or Points Plots

# %%
md_f = base_dir + 'examples/macrodata.csv'
# !cat $md_f

# %%
macro = pd.read_csv(md_f)
macro.head()
data = macro[["cpi", "m1", "tbilrate", "unemp"]]
trans_data = np.log(data).diff().dropna()
trans_data.tail()
# Out:
#           cpi        m1  tbilrate     unemp
# 198 -0.007904  0.045361 -0.396881  0.105361
# 199 -0.021979  0.066753 -2.277267  0.139762
# 200  0.002340  0.010286  0.606136  0.160343
# 201  0.008419  0.037461 -0.200671  0.127339
# 202  0.008894  0.012202 -0.405465  0.042560

# %%
ax = sns.regplot(x="m1", y="unemp", data=trans_data)
ax.set_title("Changes in log(m1) versus log(unemp)");

# %%
ax = sns.scatterplot(x="m1", y="unemp", data=trans_data)
ax.set_title("Changes in log(m1) versus log(unemp)");

# %%
sns.pairplot(trans_data, diag_kind="kde", plot_kws={"alpha": 0.2})

# %% [markdown]
# ### Face Grids and Categorical Data

# %%
display(tips.head())
# Out:
#    total_bill   tip smoker  day    time  size   tip_pct
# 0       16.99  1.01     No  Sun  Dinner     2  0.063204
# 1       10.34  1.66     No  Sun  Dinner     3  0.191244
# 2       21.01  3.50     No  Sun  Dinner     3  0.199886
# 3       23.68  3.31     No  Sun  Dinner     2  0.162494
# 4       24.59  3.61     No  Sun  Dinner     4  0.172069

# %%
sns.catplot(x="day", y="tip_pct", hue="time", col="smoker",
            kind="bar", data=tips[tips.tip_pct < 1]);

# %%
sns.catplot(x="day", y="tip_pct", row="time", col="smoker",
            kind="bar", data=tips[tips.tip_pct < 1]);

# %%
sns.catplot(x="tip_pct", y="day", 
            kind="box", data=tips[tips.tip_pct < 0.5]);
